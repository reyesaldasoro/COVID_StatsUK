# %%
import pandas as pd
import io
import requests
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import requests
from statsmodels import api as sm

# %%
url_2021='https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/weeklyprovisionalfiguresondeathsregisteredinenglandandwales/2021/copyofpublishedweek042021.xlsx'
url_2020='https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/weeklyprovisionalfiguresondeathsregisteredinenglandandwales/2020/publishedweek532020.xlsx'

# %%
cases_raw    = requests.get(url_2021).content

# %%
cases_csv    = pd.read_excel(io.StringIO(cases_raw.decode('utf-8').strip()))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-d20d13b343a9> in <module>()
# ----> 1 cases_csv    = pd.read_excel(io.StringIO(cases_raw.decode('utf-8').strip()))
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbd in position 14: invalid start byte

# %%
hdr = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"} #change the version of the browser accordingly

resp = requests.get(url_2020, headers = hdr)
pd.read_excel(resp.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-4a0412f47e87> in <module>()
#       5
#       6 resp = requests.get(url_2020, headers = hdr)
# ----> 7 pd.read_excel(resp.content)
#
# D:\Python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# D:\Python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# D:\Python\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# D:\Python\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     394             self.book = xlrd.open_workbook(self._io)
#     395         else:
# --> 396             raise ValueError('Must explicitly set engine if not passing in'
#     397                              ' buffer or path for io.')
#     398
#
# ValueError: Must explicitly set engine if not passing in buffer or path for io.

# %%
#df = pd.read_excel('publishedweek532020B.xlsx')

# %%
cases_csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f97b4985edcf> in <module>()
# ----> 1 cases_csv
#
# NameError: name 'cases_csv' is not defined

# %%
df
# Out:
#               a            b         c            d            e   f
# 0    1999-12-31  1000.000000  0.000000   0.00000000   0.00000000 NaN
# 1    2000-01-03   996.740000 -0.003260                           NaN
# 2    2000-01-04   986.991882 -0.009780                           NaN
# 3    2000-01-05   984.159216 -0.002870                           NaN
# 4    2000-01-06   982.397571 -0.001790                           NaN
# 5    2000-01-07   977.014032 -0.005480                           NaN
# 6    2000-01-10   979.759442  0.002810                           NaN
# 7    2000-01-11   993.505467  0.014030                           NaN
# 8    2000-01-12   996.257477  0.002770                           NaN
# 9    2000-01-13   994.693353 -0.001570                           NaN
# 10   2000-01-14  1004.341878  0.009700                           NaN
# 11   2000-01-17  1006.300344  0.001950                           NaN
